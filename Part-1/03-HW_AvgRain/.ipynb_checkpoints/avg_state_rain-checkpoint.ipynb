# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv('Resources/avg_rain_state.csv', low_memory=False)
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1133404e0>,
#   <matplotlib.axis.XTick at 0x1130bae10>,
#   <matplotlib.axis.XTick at 0x1130baa20>,
#   <matplotlib.axis.XTick at 0x1133fd240>,
#   <matplotlib.axis.XTick at 0x1133fd6a0>,
#   <matplotlib.axis.XTick at 0x1133fdb70>,
#   <matplotlib.axis.XTick at 0x1134070f0>,
#   <matplotlib.axis.XTick at 0x113407588>,
#   <matplotlib.axis.XTick at 0x113407b00>,
#   <matplotlib.axis.XTick at 0x113410128>,
#   <matplotlib.axis.XTick at 0x113407908>,
#   <matplotlib.axis.XTick at 0x1133fd0f0>,
#   <matplotlib.axis.XTick at 0x1134107f0>,
#   <matplotlib.axis.XTick at 0x113410d68>,
#   <matplotlib.axis.XTick at 0x113416320>,
#   <matplotlib.axis.XTick at 0x113416898>,
#   <matplotlib.axis.XTick at 0x113416e10>,
#   <matplotlib.axis.XTick at 0x11341e3c8>,
#   <matplotlib.axis.XTick at 0x11341e940>,
#   <matplotlib.axis.XTick at 0x11341eeb8>,
#   <matplotlib.axis.XTick at 0x113416940>,
#   <matplotlib.axis.XTick at 0x113410400>,
#   <matplotlib.axis.XTick at 0x113425400>,
#   <matplotlib.axis.XTick at 0x113425978>,
#   <matplotlib.axis.XTick at 0x113425ef0>,
#   <matplotlib.axis.XTick at 0x11342c4a8>,
#   <matplotlib.axis.XTick at 0x11342ca20>,
#   <matplotlib.axis.XTick at 0x11342ce80>,
#   <matplotlib.axis.XTick at 0x113432550>,
#   <matplotlib.axis.XTick at 0x11342c9e8>,
#   <matplotlib.axis.XTick at 0x1133fd780>,
#   <matplotlib.axis.XTick at 0x1134329e8>,
#   <matplotlib.axis.XTick at 0x113432f60>,
#   <matplotlib.axis.XTick at 0x113439518>,
#   <matplotlib.axis.XTick at 0x113439a90>,
#   <matplotlib.axis.XTick at 0x1134400b8>,
#   <matplotlib.axis.XTick at 0x1134405c0>,
#   <matplotlib.axis.XTick at 0x113440b38>,
#   <matplotlib.axis.XTick at 0x113440668>,
#   <matplotlib.axis.XTick at 0x113439a58>,
#   <matplotlib.axis.XTick at 0x113425780>,
#   <matplotlib.axis.XTick at 0x1134475f8>,
#   <matplotlib.axis.XTick at 0x113447b70>,
#   <matplotlib.axis.XTick at 0x11344e160>,
#   <matplotlib.axis.XTick at 0x11344e6a0>,
#   <matplotlib.axis.XTick at 0x11344ec18>,
#   <matplotlib.axis.XTick at 0x1134561d0>,
#   <matplotlib.axis.XTick at 0x113456748>,
#   <matplotlib.axis.XTick at 0x11344e748>,
#   <matplotlib.axis.XTick at 0x113432ac8>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain by State")
plt.xlabel("State")
plt.ylabel("Average Rainfall (Inches)")
# Out:
# Text(0, 0.5, 'Average Rainfall (Inches)')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/avg_state_rain.png")
plt.show()
